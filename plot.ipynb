# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # mAP

# %%
pruning_ratio = np.array([0.99,0.95,0.90,0.85,0.75,0.65,0.50,0.25,0.00])*100

unstructured_deeplift = np.array([[0.046,	0.036,	0.045,	0.03,	0.039, 0.017,	0.064,	0.027,	0.032,	0.037],
                                    [0.103,	0.097,	0.093,	0.087,	0.083, 0.074,	0.063,	0.108,	0.061,	0.132],
                                    [0.176,	0.172,	0.189,	0.191,	0.183, 0.194,	0.183,	0.182,	0.171,	0.207],
                                    [0.249,	0.242,	0.231,	0.253,	0.241,	0.222,	0.252,	0.236,	0.233,	0.255],
                                    [0.293,	0.311,	0.3,	0.304,	0.312, 0.281,	0.297,	0.304,	0.324,	0.320],
                                    [0.358,	0.343,	0.335,	0.327,	0.349,	0.339,	0.352,	0.329,	0.338,	0.309],
                                    [0.353,	0.368,	0.36,	0.352,	0.371, 0.35,    0.354,	0.367,	0.362,	0.359],
                                    [0.38,	0.379,	0.387,	0.383,	0.379, 0.396,	0.400,	0.394,	0.388,	0.383],
                                    [0.41,	0.411,	0.41,	0.411,	0.409, 0.41,    0.412,	0.410,	0.411,	0.41]])
unstructured_deeplift_mean = np.mean(unstructured_deeplift, axis=1)
unstructured_deeplift_stddev = np.std(unstructured_deeplift, axis=1)

unstructured_HYDRA = np.array([[0.062, 0.055,  0.047,   0.029,  0.052,  0.041,	0.03,	0.016,	0.073,	0.063],
                                [0.101, 0.114,  0.122,  0.120,  0.098,  0.096,	0.136,	0.099,	0.11,	0.091],
                                [0.175, 0.192,  0.190,  0.15,   0.158,  0.157,	0.172,	0.188,	0.161,	0.156],
                                [0.187,	0.218,	0.235,	0.197,	0.214,  0.228,	0.22,	0.182,	0.195,	0.221],
                                [0.279, 0.266,  0.258,  0.256,  0.267,  0.237,	0.275,	0.274,	0.274,	0.266],
                                [0.334,	0.310,	0.327,	0.300,	0.313,  0.29,	0.294,	0.317,	0.307,	0.314],
                                [0.342, 0.328,  0.323,  0.335,  0.356,  0.342,	0.328,	0.36,	0.355,	0.351],
                                [0.379, 0.366,  0.382,  0.39,   0.379,  0.382,	0.38,	0.374,	0.391,	0.387],
                                [0.411,	0.407,	0.41,   0.409,  0.411,  0.408,	0.407,	0.409,	0.413,	0.407]])
unstructured_HYDRA_mean = np.mean(unstructured_HYDRA, axis=1)
unstructured_HYDRA_stddev = np.std(unstructured_HYDRA, axis=1)

structured_deeplift = np.array([[0.048,	0.040,	0.062,	0.039,	0.052,  0.011,	0.024,	0.053,	0.058,	0.041],
                                [0.098,	0.103,	0.081,	0.102,	0.108,  0.101,	0.119,	0.11,	0.121,	0.09],
                                [0.139,	0.126,	0.139,	0.149,	0.142,  0.141,	0.152,	0.142,	0.159,	0.122],
                                [0.199,	0.182,	0.150,	0.167,	0.177,  0.165,	0.180,	0.168,	0.190,	0.187],
                                [0.22,  0.218,	0.232,	0.214,	0.230,  0.211,	0.204,	0.228,	0.239,	0.26],
                                [0.269,	0.268,	0.275,	0.269,	0.278,	0.275,	0.273,	0.274,	0.264,	0.278],
                                [0.311,	0.312,	0.313,	0.318,	0.303,  0.304,	0.323,	0.322,	0.321,	0.308],
                                [0.375,	0.369,	0.353,	0.36,	0.361,  0.363,	0.376,	0.381,	0.361,	0.365],
                                [0.409,	0.411,	0.407,	0.41,	0.411,  0.411,	0.406,	0.408,	0.418,	0.408]])
structured_deeplift_mean = np.mean(structured_deeplift, axis=1)
structured_deeplift_stddev = np.std(structured_deeplift, axis=1)

structured_HYDRA = np.array([[0.054,	0.058,	0.065,	0.057,	0.061, 0.053,	0.036,	0.04,	0.059,	0.062],
                                [0.102,	0.079,	0.081,	0.087,	0.091, 0.085,	0.084,	0.079,	0.105,	0.097],
                                [0.12,	0.115,	0.147,	0.142,	0.129, 0.143,	0.129,	0.137,	0.102,	0.143],
                                [0.163,	0.16,	0.155,	0.168,	0.16,	0.172,	0.176,	0.147,	0.164,	0.148],
                                [0.204,	0.194,	0.195,	0.186,	0.188, 0.225,	0.191,	0.209,	0.199,	0.207],
                                [0.264,	0.223,	0.239,	0.243,	0.26,	0.238,	0.246,	0.255,	0.232,	0.258],
                                [0.271,	0.309,	0.291,	0.297,	0.28,  0.282,	0.287,	0.3,    0.285,	0.282],
                                [0.352,	0.364,	0.367,	0.348,	0.349, 0.368,	0.339,	0.37,	0.359,	0.351],
                                [0.413,	0.41,	0.413,	0.411,	0.411, 0.415,	0.42,	0.413,	0.416,	0.415]])
structured_HYDRA_mean = np.mean(structured_HYDRA, axis=1)
structured_HYDRA_stddev = np.std(structured_HYDRA, axis=1)

unstructured_deeplift_greyscale = np.array([[0.034,	0.049,	0.050,	0.026,	0.044, 0.055,	0.038,	0.046,	0.042,	0.024],
                                            [0.087,	0.096,	0.11,	0.101,	0.105, 0.106,	0.111,	0.141,	0.116,	0.081],
                                            [0.175,	0.127,	0.138,	0.131,	0.18,  0.133,	0.155,	0.14,	0.133,	0.127],
                                            [0.194,	0.158,	0.161,	0.157,	0.181,	0.186,	0.184,	0.183,	0.169,	0.167],
                                            [0.201,	0.192,	0.218,	0.225,	0.218, 0.205,	0.224,	0.197,	0.214,	0.225],
                                            [0.236,	0.247,	0.228,	0.254,	0.233,	0.264,	0.224,	0.248,	0.262,	0.235],
                                            [0.281,	0.287,	0.272,	0.256,	0.267, 0.283,	0.265,	0.29,	0.284,	0.268],
                                            [0.312,	0.318,	0.321,	0.317,	0.313, 0.326,	0.319,	0.312,	0.316,	0.312],
                                            [0.329,	0.328,	0.331,	0.326,	0.331, 0.337,	0.33,	0.334,	0.33,	0.335],])
unstructured_deeplift_greyscale_mean = np.mean(unstructured_deeplift_greyscale, axis=1)
unstructured_deeplift_greyscale_stddev = np.std(unstructured_deeplift_greyscale, axis=1)

plt.figure().set_figheight(7)
# colors = ["cornflowerblue", "mediumorchid", "firebrick", "peru", "olivedrab"]
plt.axhline(y = 0.176, color = 'black', linestyle = 'dashed', label='Original Model')  

plt.plot(pruning_ratio,unstructured_deeplift_mean, "cornflowerblue", alpha=0.8, label='Unstructured DeepLIFT') # the line
plt.errorbar(pruning_ratio, unstructured_deeplift_mean, unstructured_deeplift_stddev, linestyle='None', marker='', color="cornflowerblue", ecolor="cornflowerblue", alpha=0.6, capsize=5) # error bars + dot
for i, ratio in enumerate(pruning_ratio): # scatter of actual points
    plt.scatter([ratio] * len(unstructured_deeplift[i]), unstructured_deeplift[i], c="cornflowerblue", marker='.', alpha=0.3)
    
plt.plot(pruning_ratio,unstructured_HYDRA_mean, "mediumorchid", alpha=0.8, label='Unstructured HYDRA')
plt.errorbar(pruning_ratio, unstructured_HYDRA_mean, unstructured_HYDRA_stddev, linestyle='None', marker='', color="mediumorchid", ecolor="mediumorchid", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_HYDRA[i]), unstructured_HYDRA[i], c="mediumorchid", marker='.', alpha=0.3 )
    
plt.plot(pruning_ratio,structured_deeplift_mean, "firebrick", alpha=0.8, label='Structured DeepLIFT')
plt.errorbar(pruning_ratio, structured_deeplift_mean, structured_deeplift_stddev, linestyle='None', marker='', color="firebrick", ecolor="firebrick", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(structured_deeplift[i]), structured_deeplift[i], c="firebrick", marker='.', alpha=0.3 )
    
plt.plot(pruning_ratio,structured_HYDRA_mean, "olivedrab", alpha=0.8, label='Structured HYDRA')
plt.errorbar(pruning_ratio, structured_HYDRA_mean, structured_HYDRA_stddev, linestyle='None', marker='', color="olivedrab", ecolor="olivedrab", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(structured_HYDRA[i]), structured_HYDRA[i], c="olivedrab", marker='.', alpha=0.3 )

# plt.title("mAP vs Pruning rate")
plt.xlabel("Pruning ratio (%)")
plt.ylabel("mAP")
plt.legend(loc="lower left")
plt.show()

# %%
np.set_printoptions(formatter={'float_kind':"{:.3f}".format})
temp = np.fliplr(unstructured_deeplift_greyscale.T)
print(temp)
print(temp.max(axis=0))
print(temp.min(axis=0))
print(np.mean(temp, axis=0))
np.set_printoptions(formatter={'float_kind':"{:.1e}".format})
print(np.std(temp, axis=0))
# Out:
# [[0.329 0.312 0.281 0.236 0.201 0.194 0.175 0.087 0.034]
#  [0.328 0.318 0.287 0.247 0.192 0.158 0.127 0.096 0.049]
#  [0.331 0.321 0.272 0.228 0.218 0.161 0.138 0.110 0.050]
#  [0.326 0.317 0.256 0.254 0.225 0.157 0.131 0.101 0.026]
#  [0.331 0.313 0.267 0.233 0.218 0.181 0.180 0.105 0.044]
#  [0.337 0.326 0.283 0.264 0.205 0.186 0.133 0.106 0.055]
#  [0.330 0.319 0.265 0.224 0.224 0.184 0.155 0.111 0.038]
#  [0.334 0.312 0.290 0.248 0.197 0.183 0.140 0.141 0.046]
#  [0.330 0.316 0.284 0.262 0.214 0.169 0.133 0.116 0.042]
#  [0.335 0.312 0.268 0.235 0.225 0.167 0.127 0.081 0.024]]
# [0.337 0.326 0.290 0.264 0.225 0.194 0.180 0.141 0.055]
# [0.326 0.312 0.256 0.224 0.192 0.157 0.127 0.081 0.024]
# [0.331 0.317 0.275 0.243 0.212 0.174 0.144 0.105 0.041]
# [3.2e-03 4.4e-03 1.1e-02 1.3e-02 1.2e-02 1.2e-02 1.8e-02 1.6e-02 9.7e-03]

# %%
plt.figure().set_figheight(7)
plt.axhline(y = 0.176, color = 'black', linestyle = 'dashed', label='Original Model')  

plt.plot(pruning_ratio,unstructured_deeplift_mean, "cornflowerblue", alpha=0.8, label='Unstructured DeepLIFT') # the line
plt.errorbar(pruning_ratio, unstructured_deeplift_mean, unstructured_deeplift_stddev, linestyle='None', marker='', color="cornflowerblue", ecolor="cornflowerblue", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_deeplift[i]), unstructured_deeplift[i], c="cornflowerblue", marker='.', alpha=0.3 )

plt.plot(pruning_ratio,unstructured_deeplift_greyscale_mean, "peru", alpha=0.8, label='Unstructured DeepLIFT greyscale')
plt.errorbar(pruning_ratio, unstructured_deeplift_greyscale_mean, unstructured_deeplift_greyscale_stddev, linestyle='None', marker='', color="peru", ecolor="peru", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_deeplift_greyscale[i]), unstructured_deeplift_greyscale[i], c="peru", marker='.', alpha=0.3 )

# plt.title("mAP vs Pruning rate")
plt.xlabel("Pruning ratio (%)")
plt.ylabel("mAP")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # ANOVA

# %%
from scipy.stats import f_oneway

# %%
np.set_printoptions(formatter={'float_kind':"{:.2e}".format})
print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(unstructured_HYDRA), axis=1))
print(f_oneway(np.flipud(structured_deeplift),np.flipud(structured_HYDRA), axis=1))

print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(structured_deeplift), axis=1))
print(f_oneway(np.flipud(unstructured_HYDRA),np.flipud(structured_HYDRA), axis=1))

print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(unstructured_deeplift_greyscale), axis=1))
# starts with 0 pruning, ends with 99%
# Out:
# F_onewayResult(statistic=array([2.95e+00, 3.10e+00, 1.35e+01, 1.92e+01, 4.89e+01, 2.24e+01,
#        6.04e+00, 5.17e+00, 1.89e+00]), pvalue=array([1.03e-01, 9.53e-02, 1.71e-03, 3.61e-04, 1.58e-06, 1.65e-04,
#        2.43e-02, 3.54e-02, 1.87e-01]))
# F_onewayResult(statistic=array([7.26e+00, 5.13e+00, 3.57e+01, 3.54e+01, 1.67e+01, 7.85e+00,
#        3.21e+00, 8.61e+00, 4.10e+00]), pvalue=array([1.48e-02, 3.61e-02, 1.18e-05, 1.24e-05, 6.91e-04, 1.18e-02,
#        8.99e-02, 8.87e-03, 5.81e-02]))
# F_onewayResult(statistic=array([2.10e-01, 3.19e+01, 1.98e+02, 1.95e+02, 1.47e+02, 1.30e+02,
#        7.87e+01, 2.83e+00, 7.44e-01]), pvalue=array([6.52e-01, 2.35e-05, 3.70e-11, 4.26e-11, 4.20e-10, 1.13e-09,
#        5.47e-08, 1.10e-01, 4.00e-01]))
# F_onewayResult(statistic=array([1.58e+01, 3.61e+01, 9.65e+01, 1.15e+02, 1.46e+02, 5.60e+01,
#        3.33e+01, 1.33e+01, 1.46e+00]), pvalue=array([9.00e-04, 1.12e-05, 1.18e-08, 3.06e-09, 4.44e-10, 6.27e-07,
#        1.81e-05, 1.84e-03, 2.43e-01]))
# ...

# %%
# print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(unstructured_HYDRA),np.flipud(structured_deeplift),np.flipud(structured_HYDRA), axis=1))

# %% [markdown]
# # Time

# %%
pruning_ratio = np.array([0.99,0.95,0.90,0.85,0.75,0.65,0.50,0.25,0.00])*100

unstructured_deeplift = np.array([[45.4,	41.4,	39.3,	42.9,	46.8,	43.3,	44.5,	43.2,	41.3,	44.3],
                                    [44.8,	44.7,	45.0,	44.6,	44.4,	44.6,	45.9,	46.6,	43.3,	46.0],
                                    [49.5,	49.0,	50.7,	49.7,	51.7,	50.4,	51.8,	50.9,	51.7,	48.5],
                                    [55.9,	55.8,	56.9,	57.1,	57.3,	56.5,	58.6,	58.4,	57.4,	58.4],
                                    [73.3,	73.7,	74.5,	75.2,	73.8,	75.2,	74.7,	73.7,	75.0,	72.9],
                                    [87.6,	88.3,	87.4,	89.8,	87.1,	87.0,	87.3,	88.3,	88.3,	86.1],
                                    [98.4,	100.2,	99.2,	98.2,	100.2,	99.8,	97.8,	99.0,	99.5,	97.8],
                                    [113.6,	113.6,	113.3,	113.3,	113.4,	113.3,	114.3,	113.1,	113.3,	113.6],
                                    [118.8,	119.4,	119.1,	118.9,	118.7,	118.7,	119.2,	119.1,	119.1,	118.8]])
unstructured_deeplift_mean = np.mean(unstructured_deeplift, axis=1)
unstructured_deeplift_stddev = np.std(unstructured_deeplift, axis=1)

unstructured_HYDRA = np.array([[44.1,	44.9,	41.9,	43.9,	42.0,	42.2,	42.0,	42.3,	42.3,   43.4],
                                [45.7,	44.4,	44.4,	45.8,	44.4,	44.3,	43.0,	43.0,	43.4,   45.6],
                                [50.0,	52.1,	52.5,	53.1,	52.2,	51.9,	51.8,	51.9,	52.2,   51.1],
                                [59.8,	59.2,	57.7,	59.1,	56.9,	57.3,	57.9,	55.9,	58.4,	59.9],
                                [75.0,	75.4,	74.4,	75.0,	73.1,	73.4,	74.8,	73.7,	76.9,   74.1],
                                [88.1,	87.2,	88.1,	88.4,	88.8,	88.2,	88.7,	88.6,	90.0,	87.3],
                                [100.8,	99.9,	99.8,	100.1,	100.2,	101.2,	100.3,	101.1,	98.5,   99.8],
                                [113.1,	113.7,	113.1,	113.8,	112.8,	112.9,	112.9,	113.4,	113.2,  112.1],
                                [119.5,	119.4,	119.4,	119.3,	119.5,	119.4,	119.4,	119.5,	119.5,  119.5]])
unstructured_HYDRA_mean = np.mean(unstructured_HYDRA, axis=1)
unstructured_HYDRA_stddev = np.std(unstructured_HYDRA, axis=1)

structured_deeplift = np.array([[20.1,	20.5,	23.9,	19.7,	23.2,	24.7,	24.7,	22.9,	21.2,	19.2],
                                [24.1,	20.4,	25.9,	27.6,	25.3,	23.4,	23.6,	21.4,	23.0,	25.0],
                                [24.9,	25.5,	24.5,	24.1,	25.6,	24.6,	24.9,	25.0,	27.8,	25.3],
                                [26.7,	28.0,	29.2,	30.0,	26.2,	28.3,	27.6,	27.9,	27.7,	28.5],
                                [35.1,	37.1,	38.0,	37.2,	36.6,	37.4,	37.5,	36.4,	37.0,	37.6],
                                [54.4,	53.0,	52.3,	53.1,	52.1,	52.2,	52.7,	53.0,	54.4,	52.1],
                                [81.2,	80.9,	81.3,	81.9,	80.1,	81.7,	81.4,	81.1,	81.8,	81.8],
                                [108.2,	108.0,	107.9,	108.1,	107.4,	107.8,	108.1,	107.8,	107.4,	108.1],
                                [119.4,	119.3,	119.3,	119.2,	119.7,	119.3,	119.3,	119.4,	119.5,	119.6]])
structured_deeplift_mean = np.mean(structured_deeplift, axis=1)
structured_deeplift_stddev = np.std(structured_deeplift, axis=1)

structured_HYDRA = np.array([[23.2,	23.9,	22.8,	21.8,	23.6,	24.7,	23.4,	21.6,	21.8,	22.8],
                            [24.1,	23.7,	23.0,	24.2,	25.0,	22.9,	25.3,	24.7,	25.1,	24.2],
                            [23.8,	27.0,	26.1,	27.0,	26.0,	24.5,	28.3,	25.2,	26.0,	25.2],
                            [28.3,	30.1,	27.3,	29.9,	29.9,	29.5,	28.3,	28.9,	27.6,	29.7],
                            [39.1,	37.9,	37.0,	37.9,	37.4,	37.6,	38.7,	37.1,	36.9,	37.8],
                            [53.9,	54.7,	53.7,	53.0,	53.5,	54.2,	54.9,	53.9,	55.2,	52.6],
                            [84.3,	83.1,	83.0,	82.9,	82.6,	83.0,	82.9,	82.5,	82.2,	83.3],
                            [107.2,	106.4,	106.5,	107.2,	106.6,	106.2,	107.4,	106.9,	106.8,	107.0],
                            [119.5,	119.7,	119.3,	119.4,	119.3,	119.2,	119.6,	119.3,	119.7,	119.5]])

structured_HYDRA_mean = np.mean(structured_HYDRA, axis=1)
structured_HYDRA_stddev = np.std(structured_HYDRA, axis=1)

unstructured_deeplift_greyscale = np.array([[44.5,	46.5,	42.2,	44.6,	41.6,	42.5,	36.6,	40.9,	41.2,	43.9],
                                            [42.4,	45.1,	42.3,	45.2,	42.1,	42.8,	45.4,	43.9,	44.7,	44.6],
                                            [50.2,	48.7,	51.1,	51.7,	48.8,	50.6,	49.6,	49.9,	49.8,	46.9],
                                            [57.8,	56.1,	55.0,	57.9,	56.4,	57.2,	56.8,	58.1,	57.3,	57.1],
                                            [73.6,	74.6,	73.8,	72.8,	73.4,	73.5,	73.7,	73.6,	73.4,	75.2],
                                            [86.0,	86.0,	86.6,	86.1,	85.8,	86.4,	86.5,	87.0,	86.4,	85.6],  
                                            [95.8,	97.7,	97.0,	96.4,	96.8,	97.3,	96.0,	96.9,	97.8,	96.9],
                                            [112.5,	112.0,	112.1,	111.4,	111.8,	112.4,	112.5,	111.5,	112.2,	112.6],
                                            [117.8,	118.1,	117.9,	118.1,	117.8,	118.2,	118.1,	118.3,	118.1,	118.1]])
unstructured_deeplift_greyscale_mean = np.mean(unstructured_deeplift_greyscale, axis=1)
unstructured_deeplift_greyscale_stddev = np.std(unstructured_deeplift_greyscale, axis=1)

# colors = ["cornflowerblue", "mediumorchid", "firebrick", "peru", "olivedrab"]

plt.figure().set_figheight(7)
plt.axhline(y = 119.3, color = 'black', linestyle = 'dashed', label='Original Model')  


plt.plot(pruning_ratio,unstructured_deeplift_mean, "cornflowerblue", alpha=0.8, label='Unstructured DeepLIFT') # the line
plt.errorbar(pruning_ratio, unstructured_deeplift_mean, unstructured_deeplift_stddev, linestyle='None', marker='', color="cornflowerblue", ecolor="cornflowerblue", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_deeplift[i]), unstructured_deeplift[i], c="cornflowerblue", marker='.', alpha=0.3 )
    
plt.plot(pruning_ratio,unstructured_HYDRA_mean, "mediumorchid", alpha=0.8, label='Unstructured HYDRA')
plt.errorbar(pruning_ratio, unstructured_HYDRA_mean, unstructured_HYDRA_stddev, linestyle='None', marker='', color="mediumorchid", ecolor="mediumorchid", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_HYDRA[i]), unstructured_HYDRA[i], c="mediumorchid", marker='.', alpha=0.3 )
    
plt.plot(pruning_ratio,structured_deeplift_mean, "firebrick", alpha=0.8, label='Structured DeepLIFT')
plt.errorbar(pruning_ratio, structured_deeplift_mean, structured_deeplift_stddev, linestyle='None', marker='', color="firebrick", ecolor="firebrick", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(structured_deeplift[i]), structured_deeplift[i], c="firebrick", marker='.', alpha=0.3 )
    
plt.plot(pruning_ratio,structured_HYDRA_mean, "olivedrab", alpha=0.8, label='Structured HYDRA')
plt.errorbar(pruning_ratio, structured_HYDRA_mean, structured_HYDRA_stddev, linestyle='None', marker='', color="olivedrab", ecolor="olivedrab", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(structured_HYDRA[i]), structured_HYDRA[i], c="olivedrab", marker='.', alpha=0.3 )



    
# plt.title("Time vs Pruning rate")
plt.xlabel("Pruning ratio (%)")
plt.ylabel("Time (ms)")
plt.legend(loc="lower left")
plt.show()

# %%
plt.figure().set_figheight(7)
plt.axhline(y = 119.3, color = 'black', linestyle = 'dashed', label='Original Model')  

plt.plot(pruning_ratio,unstructured_deeplift_mean, "cornflowerblue", alpha=0.8, label='Unstructured DeepLIFT') # the line
plt.errorbar(pruning_ratio, unstructured_deeplift_mean, unstructured_deeplift_stddev, linestyle='None', marker='', color="cornflowerblue", ecolor="cornflowerblue", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_deeplift[i]), unstructured_deeplift[i], c="cornflowerblue", marker='.', alpha=0.3 )

plt.plot(pruning_ratio,unstructured_deeplift_greyscale_mean, "peru", alpha=0.8, label='Unstructured DeepLIFT greyscale')
plt.errorbar(pruning_ratio, unstructured_deeplift_greyscale_mean, unstructured_deeplift_greyscale_stddev, linestyle='None', marker='', color="peru", ecolor="peru", alpha=0.6, capsize=5)
for i, ratio in enumerate(pruning_ratio):
    plt.scatter([ratio] * len(unstructured_deeplift_greyscale[i]), unstructured_deeplift_greyscale[i], c="peru", marker='.', alpha=0.3 )    

# plt.title("Time vs Pruning rate")
plt.xlabel("Pruning ratio (%)")
plt.ylabel("Time (ms)")
plt.legend(loc="lower left")
plt.show()

# %%
print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(unstructured_HYDRA), axis=1))
print(f_oneway(np.flipud(structured_deeplift),np.flipud(structured_HYDRA), axis=1))

print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(structured_deeplift), axis=1))
print(f_oneway(np.flipud(unstructured_HYDRA),np.flipud(structured_HYDRA), axis=1))

print(f_oneway(np.flipud(unstructured_deeplift),np.flipud(unstructured_deeplift_greyscale), axis=1))
# starts with 0 pruning, ends with 99%
# Out:
# F_onewayResult(statistic=array([3.53e+01, 4.17e+00, 9.20e+00, 2.33e+00, 7.55e-01, 3.52e+00,
#        1.06e+01, 1.73e+00, 1.95e-01]), pvalue=array([1.28e-05, 5.61e-02, 7.16e-03, 1.44e-01, 3.96e-01, 7.69e-02,
#        4.37e-03, 2.05e-01, 6.64e-01]))
# F_onewayResult(statistic=array([4.46e-01, 4.79e+01, 4.48e+01, 7.46e+00, 4.79e+00, 3.91e+00,
#        1.72e+00, 1.20e-01, 1.65e+00]), pvalue=array([5.13e-01, 1.81e-06, 2.80e-06, 1.37e-02, 4.21e-02, 6.36e-02,
#        2.06e-01, 7.33e-01, 2.15e-01]))
# F_onewayResult(statistic=array([2.22e+01, 1.63e+03, 2.72e+03, 6.86e+03, 1.03e+04, 3.82e+03,
#        2.61e+03, 8.19e+02, 4.89e+02]), pvalue=array([1.75e-04, 4.13e-19, 4.31e-21, 1.07e-24, 2.76e-26, 2.02e-22,
#        6.17e-21, 1.85e-16, 1.68e-14]))
# F_onewayResult(statistic=array([2.74e-02, 1.02e+03, 3.19e+03, 9.04e+03, 7.78e+03, 3.11e+03,
#        2.78e+03, 2.25e+03, 1.82e+03]), pvalue=array([8.70e-01, 2.76e-17, 1.03e-21, 8.97e-26, 3.45e-25, 1.30e-21,
#        3.55e-21, 2.36e-20, 1.56e-19]))
# ...

# %%
np.set_printoptions(formatter={'float_kind':"{:.1f}".format})
temp = np.fliplr(unstructured_deeplift.T)
print(temp)
print(temp.max(axis=0))
print(temp.min(axis=0))
print(np.mean(temp, axis=0))
np.set_printoptions(formatter={'float_kind':"{:.1e}".format})
print(np.std(temp, axis=0))
# Out:
# [[118.8 113.6 98.4 87.6 73.3 55.9 49.5 44.8 45.4]
#  [119.4 113.6 100.2 88.3 73.7 55.8 49.0 44.7 41.4]
#  [119.1 113.3 99.2 87.4 74.5 56.9 50.7 45.0 39.3]
#  [118.9 113.3 98.2 89.8 75.2 57.1 49.7 44.6 42.9]
#  [118.7 113.4 100.2 87.1 73.8 57.3 51.7 44.4 46.8]
#  [118.7 113.3 99.8 87.0 75.2 56.5 50.4 44.6 43.3]
#  [119.2 114.3 97.8 87.3 74.7 58.6 51.8 45.9 44.5]
#  [119.1 113.1 99.0 88.3 73.7 58.4 50.9 46.6 43.2]
#  [119.1 113.3 99.5 88.3 75.0 57.4 51.7 43.3 41.3]
#  [118.8 113.6 97.8 86.1 72.9 58.4 48.5 46.0 44.3]]
# [119.4 114.3 100.2 89.8 75.2 58.6 51.8 46.6 46.8]
# [118.7 113.1 97.8 86.1 72.9 55.8 48.5 43.3 39.3]
# [119.0 113.5 99.0 87.7 74.2 57.2 50.4 45.0 43.2]
# [2.2e-01 3.2e-01 8.8e-01 9.6e-01 7.8e-01 9.6e-01 1.1e+00 9.0e-01 2.1e+00]
